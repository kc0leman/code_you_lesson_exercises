# %%
# df.apply
# # if you apply the .apply function to a whole dataframe you pass one column at a time or pass one row at a time
# # if you apply the .apply function on a column of a dataframe you are passing one element at a time only in one column
# # you can apply the .map function to a series object or certain column in dataframe the function that you are passing will be applied to each element of the specified column
# # you can only use the df.applymap function on whole dataframes

# %%
import pandas as pd

# %%
data = pd.read_csv("NYC_Jobs.csv")
data.head()
# Out:
#    Job ID                         Agency Posting Type  # Of Positions  \
# 0  424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1  379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 2  520417          NYC HOUSING AUTHORITY     External               1
# 3  233549   NYC EMPLOYEES RETIREMENT SYS     External               1
# 4  510256        HUMAN RIGHTS COMMISSION     External               5
#
#                                   Business Title  \
# 0  Triage Nurse, Bureau of Public Health Clinics
# 1          CERTIFIED IT DEVELOPER (APPLICATIONS)
# 2                            Chief of Settlement
# 3  CERTIFIED IT ADMINISTRATOR (LAN/WAN), LEVEL 4
# 4              Associate Human Rights Specialist
#
#               Civil Service Title Title Classification Title Code No Level  \
# 0             PUBLIC HEALTH NURSE        Competitive-1         51011    03
# 1         CERT IT DEVELOPER (APP)        Competitive-1         13643    02
# ...

# %%
def capitalize(title):
    return title.lower().capitalize()

data['Civil Service Title'].apply(capitalize)
# Out:
# 0                  Public health nurse
# 1              Cert it developer (app)
# 2             Executive agency counsel
# 3       Certified it administrator (la
# 4       Associate human rights special
#                      ...
# 3768    Certified it administrator (la
# 3769     Associate housing development
# 3770               Senior it architect
# 3771                         Economist
# 3772           Agency attorney interne
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
def add_year(text):
    return str(text) + '_2022'

data.applymap(add_year)
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_14092\3953244785.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data.applymap(add_year)
#            Job ID                               Agency   Posting Type  \
# 0     424339_2022   DEPT OF HEALTH/MENTAL HYGIENE_2022  External_2022
# 1     379094_2022    NYC EMPLOYEES RETIREMENT SYS_2022  External_2022
# 2     520417_2022           NYC HOUSING AUTHORITY_2022  External_2022
# 3     233549_2022    NYC EMPLOYEES RETIREMENT SYS_2022  External_2022
# 4     510256_2022         HUMAN RIGHTS COMMISSION_2022  External_2022
# ...           ...                                  ...            ...
# 3768  457839_2022    NYC EMPLOYEES RETIREMENT SYS_2022  Internal_2022
# 3769  527141_2022  HOUSING PRESERVATION & DVLPMNT_2022  Internal_2022
# 3770  509443_2022      FINANCIAL INFO SVCS AGENCY_2022  Internal_2022
# 3771  352367_2022   DEPT OF HEALTH/MENTAL HYGIENE_2022  Internal_2022
# ...

# %%
# A Pandas Series is a one-dimensional labeled array in the Pandas library for Python. It is capable of holding any data type, including integers, strings, floating-point numbers, and Python objects. 

s = pd.Series(['cat', 'dog', 'NaN', 'rabbit'])
s
# Out:
# 0       cat
# 1       dog
# 2       NaN
# 3    rabbit
# dtype: object

# %%
# # .map is able to find occurences of a certain str or element and changing it immediately
# # strength of .map is if you want to change something quickly you can pass a dictionary to a map function and it will be done
# # if you try to do the same with the .apply function you would have to create a funtion to check each element to see if it changed the str or element

s.map({'cat':'kitten', 'dog':'puppy'})
# Out:
# 0    kitten
# 1     puppy
# 2       NaN
# 3       NaN
# dtype: object

# %%
# # you can also use .map using functions
# # you can either pass a dictionary to a .map function or a whole function, but you can do the same thing with .apply
# # if there is no match then .map will turn things into a missing value

def change_word(title):
    return title.replace('DEPT', 'kitten')

data['Agency'].map(change_word)
# Out:
# 0       kitten OF HEALTH/MENTAL HYGIENE
# 1          NYC EMPLOYEES RETIREMENT SYS
# 2                 NYC HOUSING AUTHORITY
# 3          NYC EMPLOYEES RETIREMENT SYS
# 4               HUMAN RIGHTS COMMISSION
#                      ...
# 3768       NYC EMPLOYEES RETIREMENT SYS
# 3769     HOUSING PRESERVATION & DVLPMNT
# 3770         FINANCIAL INFO SVCS AGENCY
# 3771    kitten OF HEALTH/MENTAL HYGIENE
# 3772            HUMAN RIGHTS COMMISSION
# Name: Agency, Length: 3773, dtype: object

# %%
# # use .map to add something to a whole column
# # if you want to apply something to just one column and not create a new function to do the function operation and just want to change the values

data['Agency'].map('This position is offered by {} '.format)
# Out:
# 0       This position is offered by DEPT OF HEALTH/MEN...
# 1       This position is offered by NYC EMPLOYEES RETI...
# 2       This position is offered by NYC HOUSING AUTHOR...
# 3       This position is offered by NYC EMPLOYEES RETI...
# 4       This position is offered by HUMAN RIGHTS COMMI...
#                               ...
# 3768    This position is offered by NYC EMPLOYEES RETI...
# 3769    This position is offered by HOUSING PRESERVATI...
# 3770    This position is offered by FINANCIAL INFO SVC...
# 3771    This position is offered by DEPT OF HEALTH/MEN...
# 3772    This position is offered by HUMAN RIGHTS COMMI...
# Name: Agency, Length: 3773, dtype: object

# %%
# # applies to all of these functions
# # when you are passing a function to them and the function cannot handle (example) 'NaN' or missing values/nonvalues

# # if there is not a number value your function may break if 'NaN' # using .ignore is essentially saying to not even pass the 'NaN' values
# s.map(function, na_action='ignore')

s.map({'cat': 'kitten', 'dog': 'puppy'}, na_action='ignore')
# Out:
# 0    kitten
# 1     puppy
# 2       NaN
# 3       NaN
# dtype: object

# %%
# Sometimes you’ll want to transform or clean values in your DataFrame, especially when preparing for analysis or visualization. Pandas gives you three powerful tools for this:

# .map() — for transforming values in a single column
# .apply() — for applying a function to each value in a column or each row
# .applymap() — for applying a function to every element in an entire DataFrame

# %%
# .map() — For Simple Substitution
# Use .map() when you want to change values in just one column, usually with a dictionary.

# # Replace values in a single column
# df['Sex'] = df['Sex'].map({'male': 'M', 'female': 'F'})

# %%
# .apply() — For Logic-Based Transformation
# Use .apply() when you want to apply a custom function to each value in a column:

# # Apply logic to a column
# df['AgeGroup'] = df['Age'].apply(lambda x: 'Senior' if x >= 60 else 'Adult')
# You can also use .apply() across rows if needed by setting axis=1.

# %%
# .applymap() — For Element-by-Element Changes in a Whole DataFrame
# Use .applymap() when you want to apply a function to every single value in an entire DataFrame (not just a single column).

# # Capitalize all string entries in a DataFrame
# df[['Name', 'Sex']] = df[['Name', 'Sex']].applymap(lambda x: x.capitalize())
# This is especially useful when:

# Cleaning up formatting
# Stripping whitespace
# Transforming all values in a smaller DataFrame (e.g., strings or currency)
# Remember: .applymap() only works on DataFrames (not Series), and it applies the function to each individual cell.

# %%
# Method	Works On	Best For
# .map()	One Column (Pandas Series)	Substitutions or simple value mapping
# .apply()	Series or DataFrames	Custom logic per value or per row
# .applymap()	Entire DataFrame	Applying a function to each cell

# # 1. Use .map() to shorten gender labels
# df['GenderCode'] = df['Sex'].map({'male': 'M', 'female': 'F'})

# # 2. Use .apply() to create an 'AgeGroup' column
# df['AgeGroup'] = df['Age'].apply(lambda x: 'Child' if x < 18 else 'Adult')

# # 3. Use .applymap() to convert all string values to lowercase in selected columns
# df[['Name', 'Sex']] = df[['Name', 'Sex']].applymap(lambda x: x.lower() if isinstance(x, str) else x)
